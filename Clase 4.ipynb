# %% [markdown]
# ## Día 4: Graficas

# %%
## pip install pandas

# %%
## pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a = plt.plot (2,3, 'X')
plt.yticks(fontsize = 17)
plt.yticks(fontsize = 17, rotation =45)

plt.xlabel('eje x', fontsize = 17)
plt.ylabel('eje y', fontsize = 17)

plt.title('un titulo', fontsize =  17)
# Out:
# Text(0.5, 1.0, 'un titulo')

# %%
data ={
    'nombres' : ['Nombre 1', 'Nombre 2', 'Nombre 3', 'Nombre 4'],
    'Edad' : [27, 30, 50, 80],
    'Peso' : [50, 60, 40, 50]
}
df = pd.DataFrame(data)
df
# Out:
#     nombres  Edad  Peso
# 0  Nombre 1    27    50
# 1  Nombre 2    30    60
# 2  Nombre 3    50    40
# 3  Nombre 4    80    50

# %%
df.plot(kind = 'line')
plt.xlabel('id de las personas', fontsize = 17)

plt.xticks(fontsize = 17, rotation = 45)
plt.yticks(fontsize = 17, rotation = 45)
plt.title('Line graph of edad y peso', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Line graph of edad y peso')

# %%
age_hist = df['Edad'].plot(kind = 'hist')
plt.ylabel('Frequency', fontsize = 17)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# ## Si exsiste alguna correlación 'Wispang' y 'CWDistance'

# %%
df = pd.read_csv('datasets/Cartwheeldata.csv')
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
import seaborn as sns

# %%
##pip install seaborn

# %%
sns.lmplot(x = 'Wingspan',
           y = 'CWDistance',
           data = df,
           fit_reg = False, # eliminar la linea de regression
           hue = 'Gender', # para ver colores por cada caterogira
          )
plt.title('Scatter plot of Wingspan vs CWDistance', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Scatter plot of Wingspan vs CWDistance')

# %%
sns.swarmplot(x = 'Gender',
              y = 'CWDistance',
              data = df
             )
plt.title('Swarm plot of Gender vs CWDistance', fontsize = 16)
plt.show()

# %% [markdown]
# ## Estadistica descriptiva

# %%
df.describe()
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
sns.boxplot(data =df.loc[df['Gender'] == 'F', 
                         ['Age', 'Height', 'Wingspan', 'CWDistance']
                        ]
           )

plt.xticks(fontsize = 17, rotation = 45)
plt.yticks(fontsize = 17)
plt.title('Boxplots', fontsize =17)
# Out:
# Text(0.5, 1.0, 'Boxplots')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1) #2 renglon, 2 columnas, 1st position
sns.boxplot(data = df.loc[df['Gender'] == 'F',
                          ['Wingspan']
                         ]
           )

ax2 = fig.add_subplot(2,2,3) #2 renglon, 2 columnas, position 3
sns.boxplot(data = df.loc[df['Gender'] == 'M',
                          ['Wingspan']
                         ]
           )

ax3 = fig.add_subplot(2,2,2) #2 renglon, 2 columnas, 2nd position
sns.boxplot(data = df.loc[df['Gender'] == 'F',
                          ['Wingspan']
                         ]
           )

ax4 = fig.add_subplot(2,2,4) #2 renglon, 2 columnas, position 4
sns.boxplot(data = df.loc[df['Gender'] == 'M',
                          ['Wingspan']
                         ]
           )

ax1.title.set_text('Genero F Wingspan')
ax2.title.set_text('Genero M Wingspan')

# %% [markdown]
# ## Histogramas con libreria 'seaborn'

# %%
sns.distplot(df.CWDistance)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x =
